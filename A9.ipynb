# %% [markdown]
# # Ninth Assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.info
# Out:
# <bound method DataFrame.info of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.std
# Out:
# <bound method DataFrame.std of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
print(df['who'].unique())
# Out:
# ['man' 'woman' 'child']

# %%
sns.boxplot(x='age', y='sex', data=df, hue='survived')
# Out:
# <Axes: xlabel='age', ylabel='sex'>

# %%
sns.displot(x='age', y='sex', data=df, hue='survived')

# %%
sns.histplot(x='age', y='sex', data=df, hue='survived')
# Out:
# <Axes: xlabel='age', ylabel='sex'>

# %%
sns.catplot(x='sex', data=df, hue='survived', kind='count')
# plt.xlim(0, 80)  # Adjust the limits as per your requirement
# plt.show()
# sns.catplot(x='age', data=df, hue='survived', kind='count')
# plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
# plt.show()

# %%
sns.catplot(x='pclass', data=df, hue='survived', kind='count')
